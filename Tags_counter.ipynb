# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import numpy as np
import os
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import ticker
import matplotlib.colors as mc
import statsmodels.formula.api as sm

# %%
gb_df = pd.read_csv('GBvideos.csv')
us_df = pd.read_csv('USvideos.csv')

# %%
# Remove unecessary columns
del_col = ['video_id','thumbnail_link','comments_disabled','ratings_disabled','video_error_or_removed','description']
us_df = us_df.drop(del_col, axis=1)

# %%
# Remove unecessary columns
del_col2 = ['video_id','thumbnail_link','comments_disabled','ratings_disabled','video_error_or_removed','description']
gb_df = gb_df.drop(del_col2, axis=1)

# %%
us_df
# Out:
#       trending_date                                              title  \
# 0          17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1          17.14.11  The Trump Presidency: Last Week Tonight with J...
# 2          17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3          17.14.11                   Nickelback Lyrics: Real or Fake?
# 4          17.14.11                           I Dare You: GOING BALD!?
# ...             ...                                                ...
# 40944      18.14.06                       The Cat Who Caught the Laser
# 40945      18.14.06                         True Facts : Ant Mutualism
# 40946      18.14.06  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947      18.14.06                How Black Panther Should Have Ended
# 40948      18.14.06  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                      nigahiga           24  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 40948              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
# [40949 rows x 10 columns]

# %%
us_df['tags'] = us_df.tags.str.replace('"', ''). replace ('|', '')

# %%
tags = us_df['tags'].str.split('|',expand=True)
tags
# Out:
#                                                       0   \
# 0                                        SHANtell martin
# 1                     last week tonight trump presidency
# 2                                        racist superman
# 3                                         rhett and link
# 4                                                   ryan
# ...                                                  ...
# 40944                                     aarons animals
# 40945                                             [none]
# 40946  I gave safiya nygaard a perfect hair makeover ...
# 40947                                      Black Panther
# 40948                                       call of duty
#
#                                    1                      2   \
# 0                                None                   None
# 1      last week tonight donald trump      john oliver trump
# 2                                rudy                mancuso
# 3                                 gmm  good mythical morning
# 4                                higa                 higatv
# ...                               ...                    ...
# 40944                          aarons                animals
# 40945                            None                   None
# 40946                      brad mondo       safiya and tyler
# 40947                           HISHE                 Marvel
# 40948                             cod             activision
#
#                                          3   \
# 0                                      None
# 1                              donald trump
# 2                                      king
# 3      rhett and link good mythical morning
# 4                                  nigahiga
# ...                                     ...
# 40944                                   cat
# 40945                                  None
# 40946                        safiya nygaard
# 40947                          Infinity War
# 40948                           Black Ops 4
#
#                                          4                 5   \
# 0                                      None              None
# 1                                      None              None
# 2                                      bach            racist
# 3      good mythical morning rhett and link  mythical morning
# 4                                i dare you               idy
# ...                                     ...               ...
# 40944                                  cats            kitten
# 40945                                  None              None
# 40946                   hair transformation          makeover
# 40947              How It Should Have Ended            parody
# 40948                                  None              None
#
#                                                   6                  7   \
# 0                                               None               None
# 1                                               None               None
# 2                                           superman               love
# 3                                          Season 12  nickelback lyrics
# 4                                               rhpc              dares
# ...                                              ...                ...
# 40944                                        kittens     prince michael
# 40945                                           None               None
# 40946  I got a perfect makeover based on my features                bts
# 40947                                         comedy      entertainment
# 40948                                           None               None
#
#                                                       8   \
# 0                                                   None
# 1                                                   None
# 2      rudy mancuso poo bear black white official mus...
# 3                         nickelback lyrics real or fake
# 4                                               no truth
# ...                                                  ...
# 40944                                             prince
# 40945                                               None
# 40946                                 hairdresser reacts
# 40947                                            wakanda
# 40948                                               None
#
#                           9   ...    59    60    61    62    63    64    65  \
# 0                       None  ...  None  None  None  None  None  None  None
# 1                       None  ...  None  None  None  None  None  None  None
# 2      iphone x by pineapple  ...  None  None  None  None  None  None  None
# 3                 nickelback  ...  None  None  None  None  None  None  None
# 4                   comments  ...  None  None  None  None  None  None  None
# ...                      ...  ...   ...   ...   ...   ...   ...   ...   ...
# 40944                michael  ...  None  None  None  None  None  None  None
# 40945                   None  ...  None  None  None  None  None  None  None
# 40946       before and after  ...  None  None  None  None  None  None  None
# 40947       Chadwick Boseman  ...  None  None  None  None  None  None  None
# 40948                   None  ...  None  None  None  None  None  None  None
#
#          66    67    68
# 0      None  None  None
# 1      None  None  None
# 2      None  None  None
# 3      None  None  None
# 4      None  None  None
# ...     ...   ...   ...
# 40944  None  None  None
# 40945  None  None  None
# 40946  None  None  None
# 40947  None  None  None
# 40948  None  None  None
#
# [40949 rows x 69 columns]

# %%
tag_list = []
for col in tags.columns:
    tag_list.extend(tags[col].to_list())
print(tag_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
from collections import Counter
Counter(tag_list)
# Out:
# Counter({'SHANtell martin': 7,
#          'last week tonight trump presidency': 7,
#          'racist superman': 57,
#          'rhett and link': 188,
#          'ryan': 188,
#          'ijustine': 111,
#          'SNL': 208,
#          '5 Ice Cream Gadgets': 6,
#          'Trailer': 702,
#          'vox.com': 107,
#          'NFL': 171,
#          'The Walking Dead': 26,
#          'marshmello': 52,
#          'nowthis': 5,
#          'shopping for new fish': 5,
#          'Robots': 3,
#          'pacific rim': 21,
#          'TED': 130,
#          'ultralight': 6,
#          'SciShow': 135,
#          'life noggin': 157,
#          'tested': 61,
#          'tom scott': 159,
#          'refinery29': 96,
#          'using other peoples showers': 7,
#          'spaghetti burrito': 5,
#          'numberphile': 49,
#          'Smart mug': 5,
#          'auth-jvardon-auth': 6,
#          'freaks and geeks': 4,
#          'carmax': 7,
#          'Amazon': 72,
#          'Eminem': 78,
#          'detective': 14,
#          'Emirates': 5,
#          'cute': 730,
#          'screenjunkies': 213,
#          'Hunter': 21,
#          'niki and gabi': 25,
#          'Nickelback': 7,
#          'U2': 26,
#          'bbc': 143,
#          '[none]': 1535,
#          'matthew santoro facts': 4,
#          'shawn johnson': 10,
#          'iphone x': 210,
#          'people are awesome': 26,
#          'NBA': 90,
#          'D3sports': 5,
#          'iPhone X': 44,
#          'nails': 143,
#          'CBS Sunday Morning': 12,
#          'wwe': 204,
#          'Jennifer Lopez ft. Wisin': 4,
#          'itsgrace': 29,
#          'Graham Norton': 111,
#          'javale mcgee': 20,
#          'KELLYANNE CONWAY ROY MOORE': 3,
#          '2017': 676,
#          "daddy's home": 3,
#          'Google': 121,
#          '7.3 magnitude earthquake': 6,
#          'vets': 3,
#          'BPG/RVG/RCA Records': 31,
#          'navy': 23,
#          'IGN': 66,
#          'wearing online dollar store makeup for a week': 3,
#          'getting my drivers license': 15,
#          'AMC': 26,
#          'christmas': 481,
#          'edsheeran': 47,
#          'best productivity apps 2017': 3,
#          'megan batoon': 29,
#          'Justice LEague': 3,
#          'Foster': 4,
#          'What What Happens live': 95,
#          'Mayo Clinic': 1,
#          'Jason Derulo': 18,
#          'James Corden': 352,
#          'Harvey Weinstein': 8,
#          'ebay': 68,
#          'Extreme Tan': 3,
#          'cave': 4,
#          'seattle': 55,
#          'ice primer': 3,
#          'BuzzFeed': 448,
#          'Game Night': 3,
#          'Little': 11,
#          'Alan Walker': 58,
#          'superfruit': 18,
#          'Chess': 11,
#          'American Broadcasting Company': 10,
#          'Giraffe': 3,
#          'how to dry a shirt in 30 seconds': 3,
#          'baby driver': 9,
#          'Kimbra': 3,
#          'capitalfmofficial': 9,
#          'iisuperwomanii': 136,
#          'Hopeless Records': 3,
#          'Japan': 64,
#          'Late Night': 137,
#          'H&M Holiday': 2,
#          'camila cabello': 173,
#          'liza': 122,
#          'owen wilson': 5,
#          'jenn im': 32,
#          'Michael Shannon': 39,
#          'Luke': 31,
#          'Niall Horan': 23,
#          'Empire': 35,
#          'NF': 2,
#          'Google Pixelbook': 2,
#          'music': 1302,
#          '11-8-17': 2,
#          'danny sapko': 2,
#          'anna wintour': 8,
#          'justice league': 60,
#          'Full Frontal with Samantha Bee': 63,
#          'nicole guerriero': 15,
#          'The Late Show': 187,
#          'jimmy': 192,
#          'SuperCarlinBrothers': 27,
#          'Sia Snowman Holiday': 2,
#          'Business Insider': 60,
#          '2CELLOS': 2,
#          'album': 129,
#          'cartoon': 372,
#          'andy': 12,
#          'Columbia': 129,
#          'nintendo': 147,
#          'Dina': 2,
#          'Jungle': 2,
#          'cbs': 81,
#          'Elbow': 2,
#          'madonna': 12,
#          'cash': 30,
#          'Sigrid': 40,
#          'Chess Club/RCA Victor': 8,
#          'the script': 11,
#          'brothers green eats': 1,
#          'Netflix': 242,
#          'tokyo': 28,
#          'paramotor': 1,
#          'improvise classical music': 1,
#          'Thirty': 1,
#          'taylor swift': 54,
#          'Keith Urban': 6,
#          'Maroon 5 SZA What Lovers Do Red Pill Blues Ellen show Ellen DeGeneres': 1,
#          'X Factor': 3,
#          "i picked my girlfriend's outfit blindfolded": 1,
#          'googlevideo': 1,
#          'chris': 36,
#          'the school of life': 63,
#          'Kardashians': 69,
#          'Whitney Port': 1,
#          '90s commercials': 1,
#          'the breakfast club': 76,
#          'enter': 1,
#          'Caterham': 1,
#          'last friday night': 1,
#          'Barbies': 1,
#          'tamar': 1,
#          'lanai': 1,
#          'GWR': 1,
#          'Blockbuster': 16,
#          'makeup': 990,
#          'james': 233,
#          'nba': 544,
#          'earthquake': 39,
#          'gopro': 72,
#          'Viral': 46,
#          'cupcakes': 64,
#          'katy perry': 138,
#          'im with her': 1,
#          'zoe sugg': 62,
#          'news': 988,
#          'selena gomez instagram full': 1,
#          'hannah': 179,
#          'Phillip': 1,
#          'YouTube': 258,
#          'Ozuna': 30,
#          'madelaine': 34,
#          'espn': 214,
#          'DubNation': 1,
#          'Technology': 105,
#          'Thanksgiving': 11,
#          'keanu reeves': 18,
#          'illustrator': 4,
#          'educational': 299,
#          'spirit airlines': 8,
#          'slomo': 85,
#          'how': 196,
#          'Jimmy Fallon': 194,
#          'lie detector': 53,
#          'batman': 75,
#          'breaking news video': 42,
#          'Dolan Twins': 25,
#          'morphe': 34,
#          'Donatella Versace': 6,
#          'DIRECTV': 8,
#          'venting online': 7,
#          'easy life hacks': 20,
#          'First we feast': 153,
#          'Brian Hull': 18,
#          'laser cutter': 77,
#          'access hollywood': 16,
#          'American Things Europeans Find Weird': 6,
#          'emma chamberlain': 5,
#          'the room': 42,
#          'abc': 128,
#          'Colin': 1,
#          'summit': 5,
#          'Taylor swift Instagram Story': 6,
#          'breath': 5,
#          'Ice Boats': 2,
#          'victoria beckham': 2,
#          'red bull': 55,
#          'Demi Lovato': 50,
#          'unisex': 4,
#          'fei fei sun': 11,
#          'Todrick Hall': 22,
#          'Jeep': 4,
#          'ham': 18,
#          'Hanson': 4,
#          'ION Bottleless Water Cooler': 4,
#          'Sirah': 5,
#          'Rick and Morty': 4,
#          'Valk Aviation': 2,
#          'galexy note 8': 4,
#          'HuskerOnline.com': 3,
#          'essiebutton': 3,
#          'the office': 22,
#          'lord of the rings tv show': 5,
#          'Arizona': 2,
#          'bkav': 2,
#          'dapulse': 3,
#          'canada': 121,
#          'TMZ': 70,
#          'box': 46,
#          'Forest': 7,
#          'tanner': 20,
#          'first date': 7,
#          'Justice league': 2,
#          'kim': 27,
#          'Fall Out Boy': 21,
#          'alt-j': 7,
#          'Luis Fonsi': 15,
#          'kickflip': 6,
#          'wonder woman': 41,
#          'tech': 287,
#          'Zodiac': 12,
#          'Kim Kardashian': 189,
#          'Dashboard Confessional': 18,
#          'john green': 125,
#          'jillian vessey': 18,
#          'showtime': 19,
#          'Titanic': 15,
#          'Atlanta Hawks': 3,
#          'tobeornottobethatisthequestion': 65,
#          'animal': 50,
#          'maths': 16,
#          'remy ma': 5,
#          'documentary': 551,
#          'BBC': 160,
#          'clean bandit': 43,
#          'sarasota': 4,
#          'Vostok.bike': 2,
#          'Oregon': 14,
#          'lord of the rings tv series': 2,
#          'MMA': 27,
#          'crab': 1,
#          'Robotics': 15,
#          'Rampage': 6,
#          'horror movie': 21,
#          'bob saget': 7,
#          'miranda sings': 49,
#          'Luis': 10,
#          'emergence': 8,
#          '73 qs': 14,
#          'BIGHIT': 80,
#          'diy': 622,
#          'OnePlus 5T': 2,
#          'jacksfilms': 76,
#          'The Talk': 26,
#          'i tried period yoga pants': 3,
#          'Blake': 24,
#          'The Tonight Show': 186,
#          'surface book': 6,
#          'pixel buds': 3,
#          'Christmas': 100,
#          'Collegehumor': 143,
#          'Justice League': 32,
#          'auth-jking413-auth': 7,
#          'victoria secret fashion show': 11,
#          'Face ID Fail': 8,
#          'Batman': 28,
#          'blissing me': 6,
#          'DJ Snake': 7,
#          'iPhone X Review': 8,
#          'game theory': 47,
#          'Music video': 5,
#          'science': 1111,
#          'Get It Right Diplo feat. Mø': 13,
#          'dua lipa': 113,
#          'spa': 15,
#          'Philadelphia': 23,
#          'story': 109,
#          'Kesha': 43,
#          'Devel': 4,
#          'The TODAY Show': 102,
#          'industrial': 41,
#          'auralnauts': 2,
#          '60 Minutes': 4,
#          'Paramore': 16,
#          'Chris': 38,
#          'taxes': 28,
#          'Red Velvet': 35,
#          'Green Day': 12,
#          'Hailee': 25,
#          'Most dangerous drug': 7,
#          'Cheerios': 4,
#          'Yas Queen': 1,
#          'the': 315,
#          'real life lore': 22,
#          'ultra records': 12,
#          'the real': 42,
#          'dice': 8,
#          'lovelaurenelizabeth': 5,
#          'huge haul': 3,
#          'the rest of our life': 5,
#          'funnyordie': 11,
#          'Real Time': 71,
#          'thanksgiving': 121,
#          'LAUV': 16,
#          'UCLA': 14,
#          'ranz': 16,
#          'pencils': 4,
#          'nbc news': 71,
#          'motor sport': 6,
#          'MisterWives': 5,
#          'littleBits': 3,
#          'religion of sports': 3,
#          'words': 15,
#          'Pixar': 55,
#          'Selena': 44,
#          'pumpkin': 21,
#          'Thomas Sanders': 32,
#          'GT Series': 8,
#          'Tesla Roadster': 15,
#          'chicken parm pizza': 7,
#          'nile wilson': 11,
#          'anthony padilla': 70,
#          'rclbeauty101': 8,
#          'maddie': 22,
#          'good morning britain': 7,
#          'Sia Ho Ho Ho Holiday': 10,
#          'Tove': 11,
#          'Imagine': 40,
#          'Chloe x Halle': 35,
#          'julia roberts': 3,
#          'fsu': 3,
#          'Textron': 3,
#          'Tegan and Sara': 3,
#          'amazon': 209,
#          'DNS': 3,
#          'Gin Wigmore': 2,
#          'Kpop': 39,
#          'corgi': 14,
#          'a wrinkle in time': 25,
#          'Dwarf': 8,
#          'i dressed like it was 1977': 8,
#          'Gordon': 61,
#          'soap stairs': 8,
#          'American Music Awards': 47,
#          'HBO': 126,
#          'American Influencer Awards': 7,
#          'taylor nicole dean': 28,
#          'submarine': 8,
#          'Tesla': 46,
#          'vpcwochit': 7,
#          'Late night': 19,
#          'new orleans videos': 7,
#          'Nifty': 26,
#          'Boeing787': 6,
#          'Tech Insider': 39,
#          'ByStorm Entertainment/RCA Records': 28,
#          'mali music and jennifer hudson': 3,
#          'matoma': 3,
#          'Jessie': 8,
#          'Only You': 8,
#          'Lifestyle': 99,
#          'Coping': 2,
#          'Georgia Dome': 8,
#          'musical fiction': 15,
#          'movie hells': 6,
#          'hairstyle': 53,
#          'every blank ever': 93,
#          'sp:dt=2017-11-19T20:30:00-05:00': 7,
#          'Bruno Mars': 20,
#          'the weather channel': 9,
#          'al franken': 21,
#          'mashed potatoes': 7,
#          'shorts': 96,
#          'the grand tour': 17,
#          'kelly clarkson': 107,
#          'AMA Awards': 7,
#          'Jon Stewart': 9,
#          'veritasium': 19,
#          'Josh Groban': 15,
#          'baby': 193,
#          'Billboard': 52,
#          'mc Donalds': 8,
#          'OnePlus 5t': 7,
#          'Breaking Bad': 11,
#          "Marvel's Agents of SHIELD Season 5": 8,
#          'simonandmartina': 34,
#          'Alisha Marie': 48,
#          'fleurdeforce': 18,
#          'Access Hollywood': 7,
#          'Passenger': 7,
#          'klossy': 43,
#          'mcdonalds': 93,
#          'future': 144,
#          'burger': 62,
#          'Thegn Thrand': 5,
#          'leroy': 12,
#          'fizz': 4,
#          'lindsey': 34,
#          '3D printed': 2,
#          'clear pumpkin pie': 8,
#          'polyphonic': 2,
#          'freeform': 1,
#          'autocomplete': 32,
#          'Beautiful Trauma': 9,
#          'friends': 267,
#          'video': 890,
#          'hot sauce': 100,
#          'love': 430,
#          'Casey Neistat': 27,
#          'Razer Phone': 24,
#          'Sofia Vergara': 1,
#          'nbc the voice': 24,
#          'liza koshy': 94,
#          'the walking dead no mans land by hannah stocking anwar jibawi inanna sarkis': 20,
#          'nuclear': 34,
#          'the walking dead no mans land by inanna sarkis hannah stocking anwar jibawi': 7,
#          'beauty': 695,
#          'Shawn Mendes': 63,
#          'NASA': 46,
#          'tyler oakley': 63,
#          'Tarte': 16,
#          'how to': 1604,
#          'YTN': 8,
#          'Connor Franta': 32,
#          'alex gilbert': 7,
#          'Colleen': 7,
#          'latest News': 180,
#          'Game Show': 8,
#          'cooking': 802,
#          'rocket': 33,
#          'black friday': 36,
#          'terry crews': 24,
#          'rick and morty': 50,
#          'Jim Carrey': 8,
#          'proto putty': 1,
#          "Sia Santa's Coming For Us Holiday": 8,
#          'https://www.gofundme.com/pmxux-hope-for-holly': 8,
#          "tv's": 8,
#          'the walking dead no mans land by anwar jibawi hannah stocking inanna sarkis': 17,
#          'derek blasberg': 11,
#          'allen pan': 20,
#          'cars 3': 6,
#          'Lady': 30,
#          'Brat': 7,
#          'kandee johnson': 38,
#          'women owned makeup brands': 7,
#          'the nerdwriter': 62,
#          'channing': 10,
#          'Christina Aguilera': 36,
#          'miranda': 30,
#          'Bird (Animal)': 11,
#          'Pentatonix': 112,
#          'deal guy': 10,
#          'sneaking into': 7,
#          'Car': 36,
#          'Tommy Edison': 6,
#          'mylifeaseva': 18,
#          '12 Strong': 3,
#          'twitch': 14,
#          'zendaya': 46,
#          'football': 347,
#          'screen junkies news': 56,
#          'portugal the man': 7,
#          'Kelly Clarkson': 166,
#          'thr': 44,
#          'Nick Jonas': 32,
#          'green day': 6,
#          'most expensive steak': 5,
#          'CBS 4 News Morning': 6,
#          'Amazon Alexa': 5,
#          'christina aguilera': 14,
#          'Fall': 59,
#          '1989': 11,
#          'Awards': 72,
#          'nichrome': 4,
#          'Hackaday': 5,
#          'airpods': 13,
#          'mousetrap car': 19,
#          'Neymar': 6,
#          'hackaday': 5,
#          'Royal Academy of Arts': 5,
#          'ford fairlane': 4,
#          'Mcdonalds': 11,
#          'Marvel Comics': 89,
#          'panel': 11,
#          'Mase': 7,
#          'ok go': 7,
#          'live stream': 14,
#          'late night': 627,
#          'Smallfoot': 15,
#          'olaf': 10,
#          'alex jones': 10,
#          'Beach': 4,
#          'All Star': 4,
#          'elle': 46,
#          'Charlie Brooker': 17,
#          'casually explained': 22,
#          'DIY': 470,
#          'buzzfeed': 333,
#          'VR': 31,
#          'phil is not on fire': 6,
#          'electric car': 54,
#          'chef vitale': 26,
#          'matpat': 151,
#          'fail compilation': 9,
#          'dog bath': 12,
#          '4 Ways to Style a Black Bodysuit ': 6,
#          'Music': 362,
#          'iPhone Mod': 5,
#          'Pitch Perfect': 113,
#          'Harry Connick Jr.': 4,
#          'crossbow': 18,
#          'SAOIRSE': 3,
#          'jontron': 6,
#          'Cracked': 20,
#          'Dorkly': 6,
#          'Mount Agung': 6,
#          'markiplier makes': 5,
#          'j.t. barrett': 6,
#          'Hacks': 6,
#          'marvel': 432,
#          'Miss Universe': 6,
#          'bethany mota': 5,
#          'keeping up with the gonzalezs pt 3': 18,
#          'mornings': 4,
#          'hanyuqiao': 5,
#          'how to make a gift box out of paper easy': 4,
#          'sharing things': 4,
#          'clothmap': 3,
#          'Gatorade': 12,
#          'Scene (drama)': 2,
#          'Becky G': 28,
#          'star wars': 284,
#          'ellie and jared': 13,
#          'spyker c8': 7,
#          'Meghan Markle': 94,
#          'women in comedy': 11,
#          'crocep': 2,
#          'BTS': 188,
#          "cam'ron": 5,
#          'battle with charlie puth': 8,
#          'the x factor': 13,
#          'Calgary Stampeders vs Toronto Argonauts': 5,
#          'Jamaica': 12,
#          'west midlands police': 5,
#          'santa': 71,
#          'which programming language to learn first': 4,
#          'WEB': 4,
#          'katana': 4,
#          'Bending water': 4,
#          'Pop': 1280,
#          'shane meadows': 3,
#          'laser': 74,
#          'The Real Housewives of Atlanta': 3,
#          'Linkin Park': 38,
#          'Too Faced': 2,
#          'cheese': 94,
#          'Nick': 51,
#          'sevdaliza': 1,
#          'shanedawsontv': 9,
#          'screen junkies': 213,
#          'arrival': 16,
#          'friend zone texts': 8,
#          'the voice': 188,
#          'money': 138,
#          'Variety': 23,
#          'bts': 227,
#          'Daisy': 7,
#          'kane brown deluxe': 15,
#          'dunkin donuts': 12,
#          'youtube quiz': 4,
#          'mario': 51,
#          'how to make pancakes': 7,
#          'coming out': 32,
#          'creed': 13,
#          'mike boyd': 63,
#          'simonscat': 115,
#          'apartment tour': 47,
#          'Wassabi': 18,
#          'Grammys 2018': 26,
#          'Darren Criss I Don’t Mind': 5,
#          'smartphone giveaway': 5,
#          'finding a boyfriend for the holidays': 23,
#          'Imagine Dragons Thunder Evolve Ellen DeGeneres Ellen show': 5,
#          'andrew': 74,
#          'Zero Mass Water': 5,
#          'best electric skateboard 2017 2018': 5,
#          'STEVE': 9,
#          'great big story': 128,
#          'banking': 9,
#          'Paddington': 6,
#          'Legofreedom1': 5,
#          '2018 grammy': 5,
#          'hm': 6,
#          'Timothée chalamet': 6,
#          'how to take a screenshot on iPhone': 2,
#          'Harry Styles': 11,
#          'hillary clinton': 21,
#          'Mike Weber': 4,
#          'lucy moon': 12,
#          'glass': 22,
#          "jack avery daniel seavey taking you zach herron corbyn besson jonah marais why don't we": 3,
#          'saintly': 3,
#          'Damascus steel': 3,
#          'lyrics': 230,
#          'Furby': 2,
#          'lamborghini': 29,
#          'new snapchat': 17,
#          'fluidized bed': 8,
#          'mark wahlberg': 9,
#          'Sam': 44,
#          'Kylie Jenner': 96,
#          'Telegraph': 8,
#          'All The Money In The World': 8,
#          'lebron': 128,
#          'kylie jenner': 151,
#          'fashion': 571,
#          'Joe Keery': 12,
#          'Armie': 7,
#          'max brenner chocolate': 6,
#          'coco': 27,
#          'karlie kloss': 47,
#          'Entertainment Tonight': 30,
#          'nitrov2': 6,
#          'ironied': 7,
#          'feel': 6,
#          'car chase': 5,
#          'howto': 69,
#          'prince william': 24,
#          'rainsford': 4,
#          'billboard news': 4,
#          'Downtown': 24,
#          'DACA': 9,
#          'Chriselle Lim': 3,
#          'Chuck': 6,
#          'The New York Times': 38,
#          'anna': 61,
#          'Avengers': 106,
#          'rylo camera': 7,
#          'Chelsea': 5,
#          'j balvin willy william mi gente alesso remix with anwar jibawi': 7,
#          'animal video': 83,
#          'colin': 72,
#          'corinne': 7,
#          'Liu Yifei Mulan': 7,
#          'I Pretended To Be A Model On A Shoot For Jigsaw': 7,
#          'CYN': 7,
#          'Magikarp': 7,
#          'british': 180,
#          'usatsyn': 43,
#          'homeless': 58,
#          'travel': 280,
#          'Focus Features': 77,
#          'News': 256,
#          'Galantis': 5,
#          "POPSUGAR Girls' Guide": 4,
#          'how to add email attachments on iPhone': 3,
#          'DraftExpress': 2,
#          'spacewalk': 7,
#          'pets': 349,
#          'truTV': 33,
#          'joy behar': 1,
#          'billboard': 49,
#          'Reactception': 7,
#          '방탄소년단': 146,
#          'nickelodeon': 50,
#          'ed sheeran': 166,
#          'Juicy': 3,
#          'Five': 31,
#          'midnight sun': 7,
#          'Martin Garrix': 20,
#          'ice cream rolls': 7,
#          'Mattlauer': 2,
#          'Jolly': 22,
#          'Cooking Vinyl': 11,
#          'No More': 6,
#          'FIFA': 6,
#          'HihoKids': 1,
#          'TBS': 111,
#          'genius': 58,
#          'The': 228,
#          'Meghan Markle (TV Actor)': 1,
#          'wengie': 7,
#          'satisfying': 80,
#          'bedroom makeover': 6,
#          'jordan peele': 52,
#          'ニンジャバットマン': 6,
#          'communitychannel': 6,
#          'Star Wars': 218,
#          'day in my life': 8,
#          'Sia Candy Cane Lane Holiday': 6,
#          'japan': 139,
#          'Karlie Kloss': 10,
#          'james arthur': 24,
#          'tessa violet': 8,
#          'KIm K': 2,
#          'sneakerhead': 134,
#          'MOBO': 4,
#          'pug': 7,
#          'Pie': 3,
#          'raspbery pi': 3,
#          '5-Minute Crafts': 22,
#          'the invention of chapstick': 7,
#          'Water Bottle Gadgets': 8,
#          'Ohio State Buckeyes': 7,
#          'leyden jar': 7,
#          'pizza pouch': 7,
#          'latino hunger games': 13,
#          'food ranger': 37,
#          'Pizza kit': 5,
#          'beamazed': 5,
#          'big': 63,
#          'Tom Daley': 10,
#          'this morning': 5,
#          'Xscape': 7,
#          'thirty': 15,
#          'nfl': 88,
#          'First Aid Kit': 4,
#          'innovation': 54,
#          'iMovie': 4,
#          'water bottle': 3,
#          'Joe Rogan': 2,
#          'Arduino': 1,
#          'Lil': 8,
#          'Jurassic World': 38,
#          'thomas the tank engine': 8,
#          'Alessandra Ambrosio': 7,
#          'TMZ2016FS11221': 25,
#          'Grace VanderWaal': 25,
#          'life hacks': 109,
#          'tiffany': 2,
#          'ohio state buckeyes': 12,
#          'Shay Mitchell': 13,
#          'pontiac line': 4,
#          'gigi': 17,
#          'almazan kitchen': 2,
#          'spiderman': 42,
#          'chicken': 36,
#          'dude perfect': 168,
#          'Broke': 19,
#          'mlg highlights': 53,
#          'Ellen': 93,
#          'tanya burr': 20,
#          'John Conyers': 11,
#          'karina garcia': 6,
#          'EXO': 22,
#          'TWICE Heart Shaker': 12,
#          'kissfmuk': 6,
#          'Bloomberg': 14,
#          'John Green': 6,
#          'kayleymelissa': 22,
#          'magnolia pictures': 17,
#          'nat geo live': 5,
#          'accidents': 6,
#          'Jack and Dean': 20,
#          'Men’s Fashion Tips & Winter 2017 Style Guide': 4,
#          'Neil Young': 2,
#          'rich': 28,
#          'Rewind': 10,
#          'Jurassic': 8,
#          'Pokémon': 52,
#          '08282016NtflxUSCAN': 187,
#          'runaway bride': 20,
#          'grand tour': 12,
#          'india': 66,
#          'CBS 2 News Evening': 23,
#          'evacuate': 13,
#          'Syracuse University': 5,
#          'blue planet': 14,
#          'lifetime': 5,
#          'outback steakhouse': 4,
#          'Daisy Ridley': 33,
#          'elf': 9,
#          'Saoirse': 10,
#          'mashup': 13,
#          'Fox Friends': 2,
#          'MickMake': 1,
#          'PRETTYMUCH': 9,
#          'rabbit saved': 7,
#          'et': 74,
#          'universal basic income': 7,
#          'KUKA': 7,
#          'campo santo': 7,
#          'snl': 371,
#          'building our dream home': 6,
#          'gordon Ramsay it’s raw': 19,
#          'Allison': 12,
#          'tariq nasheed': 6,
#          'E! Entertainment': 45,
#          'tonya harding': 28,
#          'youtube': 253,
#          'simply nailogical': 97,
#          'Morning Joe': 24,
#          'Pittsburgh Dad': 6,
#          'mario cereal': 6,
#          'challenge': 659,
#          'mental health': 110,
#          "CES 2018 Honda's New Robotics Concept": 6,
#          'The CW': 38,
#          'SCIENTISTS WANT TO BAN GLITTER!! The best day of my life!': 5,
#          'talking': 21,
#          'colleen ballinger': 42,
#          'turtles all the way down': 32,
#          'uk news': 10,
#          'granola': 5,
#          'net neutrality': 18,
#          'alissa ashley': 34,
#          'princess': 45,
#          'pixielocks': 18,
#          'Marteen': 5,
#          'Lumio': 2,
#          'weather': 75,
#          'Grown-ish': 11,
#          'hack': 60,
#          'gender': 24,
#          'National Safety Council': 3,
#          'best carol burnett show bloopers': 4,
#          'WHTA': 3,
#          'Zoetrope': 1,
#          'Migos': 51,
#          'the game awards': 11,
#          'mouse': 25,
#          'Gwen': 3,
#          'fanfiction reading': 3,
#          'Louis Tomlinson': 6,
#          'PUBG': 7,
#          'kelly ripa': 42,
#          'utopia': 23,
#          'marzia': 59,
#          'dan and phil': 14,
#          'Whitney Avalon': 6,
#          '7-eleven makeup': 5,
#          'leona lewis': 12,
#          'LEGO': 14,
#          'Merrell Twins': 36,
#          'Greyson Chance': 5,
#          'California': 30,
#          'Liam': 31,
#          'charli': 6,
#          'mariah carey': 12,
#          'me too movement': 4,
#          'movies': 540,
#          'Tom Thum': 3,
#          'VidCon': 3,
#          'photography': 20,
#          'raspberrypi': 1,
#          'youtube rewind 2017': 24,
#          'house tour': 90,
#          'hailee steinfeld wont let me go': 6,
#          'DESI PERKINS': 34,
#          'art': 157,
#          'Unipiper': 5,
#          'John Maclean': 4,
#          'kpop': 134,
#          'benbrown': 4,
#          'Michael': 19,
#          'taylor r': 2,
#          'ready player one': 53,
#          'bad lip reading': 63,
#          'poppy': 37,
#          'i dressed according to my zodiac sign for a week': 6,
#          'Tasty': 127,
#          'environment': 95,
#          'PC': 80,
#          'jennxpenn': 38,
#          'Alita': 1,
#          'Tiffany': 4,
#          'virtuoso': 4,
#          'ISIS defeated in Iraq': 3,
#          'STM32': 3,
#          'AreWeFamousNow': 4,
#          'movie': 734,
#          'Flite Test': 16,
#          'holy grail': 3,
#          'logan paul vlog': 24,
#          'angry grandpa': 8,
#          'i wont wear a jacket': 10,
#          'CNBC': 35,
#          'MSNBC': 49,
#          'national geographic': 82,
#          'Donald Trump': 126,
#          'jennifer': 17,
#          'SONY PICTURES': 13,
#          'GoPro': 31,
#          'celebrity': 930,
#          'trump sexual harassment': 5,
#          'Inthefrow': 4,
#          "victoria's secret": 33,
#          'Moby': 6,
#          'Brett': 17,
#          'samantha': 9,
#          'apple inc.': 4,
#          'advice': 112,
#          'John Boyega': 39,
#          'viralhog': 36,
#          'compress': 3,
#          'donald trump': 180,
#          'yt:cc=on': 91,
#          'best tongue twister': 2,
#          'Trevor': 1,
#          'rogue one': 32,
#          'Emirates first class': 7,
#          'Dwayne Johnson': 24,
#          'vlogbrothers': 66,
#          'Star Wars: The Last Jedi': 26,
#          'tech 2017': 10,
#          'What Is The Most Common Crime In Different Countries': 7,
#          'iMac Pro': 23,
#          'Apple': 102,
#          'jennifer hudson': 55,
#          'daisyridley': 6,
#          'tori': 6,
#          'Ed Sheeran': 32,
#          'Vice': 17,
#          'maccabeats': 6,
#          'rey': 45,
#          'the bachelor': 50,
#          'Tig Notaro': 4,
#          'cyberbully': 5,
#          'The cuddle squad': 5,
#          'ilikeweylie': 5,
#          'anthem lights': 5,
#          'Sheryl Crow': 4,
#          'rudy mancuso maia mitchell sirens official music video': 1,
#          'rjfs': 4,
#          'the gate deconstructed': 6,
#          'nobel peace prize concert': 3,
#          'worldstar': 6,
#          'review': 1005,
#          'google home mini': 3,
#          'Birdbox studio': 1,
#          'Marcus Butler': 1,
#          'comedy': 2931,
#          'Jeff VanderMeer': 14,
#          'joe biden': 1,
#          'google': 162,
#          'Pitch perfect': 1,
#          'DJ Earworm': 7,
#          'compliment': 2,
#          'brian johnson': 7,
#          'jaclynhill1': 46,
#          'Selena Gomez': 32,
#          'Chris Brown feat. AGNEZ MO': 7,
#          'anti santa': 6,
#          'T-Mobile': 7,
#          'ThePianoGuys': 6,
#          'Loreta Frankonyte': 15,
#          'Sam Smith': 15,
#          'the 15:17 to paris': 6,
#          'carly and erin': 5,
#          'Gwen Stefani Blake Shelton You Make It Feel Like Christmas NBC': 6,
#          'Senate': 50,
#          'chit chat': 17,
#          "this one's for you": 6,
#          'keaton jones': 16,
#          'dreams': 16,
#          'Drone': 7,
#          'travel smarter': 12,
#          'Glambag': 4,
#          'the atlantic': 11,
#          'Stranger things': 4,
#          'VICE News Tonight': 32,
#          'schoolshooting': 5,
#          'Ellie': 17,
#          'Rob Scallon': 26,
#          'Penguin Books UK': 2,
#          'dr pimple popper': 12,
#          'cocktail': 155,
#          'invisible box challenge': 8,
#          'fcc net neutrality': 4,
#          ...})

# %%
tag_list.most_common()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-9283264f988a> in <module>
# ----> 1 tag_list.most_common()
#
# AttributeError: 'list' object has no attribute 'most_common'
