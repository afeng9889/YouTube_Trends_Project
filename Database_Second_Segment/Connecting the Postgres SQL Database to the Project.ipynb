# %% [markdown]
# This section of code will be used to show how we are connecting our SQL Postgres Database with our project. We will be connecting our Postgres SQL database to Pandas. No API or webscraping is being done to extract data. Our data source was Kaggle and a raw CSV file. The SQL Database was created and the CSV file has been split into 5 tables. The ERD and the queries to create the table and the join are also provided in the repository.

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %%
db_string = f"postgres://postgres:hello@127.0.0.1:5432/Youtube_Trends_Project"

# %%
engine = create_engine(db_string)

# %%
df_us1 = pd.read_sql_query('select * from "us_videos_1"',con=engine)

# %%
df_us1
# Out:
#           video_id   likes  dislikes  comment_count  \
# 0      2kyS6SvSYSE   57527      2966          15954
# 1      1ZAPwfrtAFY   97185      6146          12703
# 2      5qpjK5DgCt4  146033      5339           8181
# 3      puqaWrEC7tY   10172       666           2146
# 4      d380meD0W0M  132235      1989          17518
# ...            ...     ...       ...            ...
# 40944  BZt0qjTWNhw   38160      1385           2657
# 40945  1h7KV2sjUWY   60008       382           3936
# 40946  D6Oy4LfoqsU   48068      1032           3992
# 40947  oV0zkMe1K8s  192957      2846          13088
# 40948  ooyjaVdt-jA  357079    212976         144795
#
#                                        thumbnail_link comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg             FALSE
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg             FALSE
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg             FALSE
# ...

# %%
df_us2 = pd.read_sql_query('select * from "us_videos_2"',con=engine)
df_us2
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2                         Racist Superman | Rudy Mancuso
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
df_us3 = pd.read_sql_query('select * from "us_videos_3"',con=engine)
df_us3
# Out:
#           video_id                                               tags
# 0      2kyS6SvSYSE                                    SHANtell martin
# 1      1ZAPwfrtAFY  last week tonight trump presidency|last week t...
# 2      5qpjK5DgCt4                           2017-11-12T19:05:24.000Z
# 3      puqaWrEC7tY  rhett and link|gmm|good mythical morning|rhett...
# 4      d380meD0W0M  ryan|higa|higatv|nigahiga|i dare you|idy|rhpc|...
# ...            ...                                                ...
# 40944  BZt0qjTWNhw  aarons animals|aarons|animals|cat|cats|kitten|...
# 40945  1h7KV2sjUWY                                             [none]
# 40946  D6Oy4LfoqsU  I gave safiya nygaard a perfect hair makeover ...
# 40947  oV0zkMe1K8s  Black Panther|HISHE|Marvel|Infinity War|How It...
# 40948  ooyjaVdt-jA            call of duty|cod|activision|Black Ops 4
#
# [40949 rows x 2 columns]

# %%
df_us4 = pd.read_sql_query('select * from "us_videos_4"',con=engine)
df_us4
# Out:
#           video_id              publish_time    views_
# 0      2kyS6SvSYSE  2017-11-13T17:13:01.000Z    748374
# 1      1ZAPwfrtAFY  2017-11-13T07:30:00.000Z   2418783
# 2      5qpjK5DgCt4  2017-11-12T19:05:24.000Z   3191434
# 3      puqaWrEC7tY  2017-11-13T11:00:04.000Z    343168
# 4      d380meD0W0M  2017-11-12T18:01:41.000Z   2095731
# ...            ...                       ...       ...
# 40944  BZt0qjTWNhw  2018-05-18T13:00:04.000Z   1685609
# 40945  1h7KV2sjUWY  2018-05-18T01:00:06.000Z   1064798
# 40946  D6Oy4LfoqsU  2018-05-18T17:34:22.000Z   1066451
# 40947  oV0zkMe1K8s  2018-05-17T17:00:04.000Z   5660813
# 40948  ooyjaVdt-jA  2018-05-17T17:09:38.000Z  10306119
#
# [40949 rows x 3 columns]

# %%
df_us5 = pd.read_sql_query('select * from "us_videos_5"',con=engine)
df_us5
# Out:
#           video_id                                        description
# 0      2kyS6SvSYSE  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      1ZAPwfrtAFY  One year after the presidential election, John...
# 2      5qpjK5DgCt4  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► ...
# 3      puqaWrEC7tY  Today we find out if Link is a Nickelback amat...
# 4      d380meD0W0M  I know it's been a while since we did this sho...
# ...            ...                                                ...
# 40944  BZt0qjTWNhw     The Cat Who Caught the Laser - Aaron's Animals
# 40945  1h7KV2sjUWY                                               None
# 40946  D6Oy4LfoqsU  I had so much fun transforming Safiyas hair in...
# 40947  oV0zkMe1K8s  How Black Panther Should Have EndedWatch More ...
# 40948  ooyjaVdt-jA  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40949 rows x 2 columns]
