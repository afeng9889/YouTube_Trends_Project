# %% [markdown]
# ## Import our dependencies

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import numpy as np
import os
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import ticker
import matplotlib.colors as mc

# %% [markdown]
# ## Import and read csv files

# %%
gb_df = pd.read_csv('GBvideos.csv')
us_df = pd.read_csv('USvideos.csv')

# %%
us_df.head(5)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
us_df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
gb_df.head(5)
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
gb_df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %% [markdown]
# ## Clean up dataframes

# %%
# Change trending_date to datetime format
us_df['trending_date'] = pd.to_datetime(us_df['trending_date'],format='%y.%d.%m')

# %%
# Change publish_time to datetime format
us_df['publish_time'] = pd.to_datetime(us_df['publish_time'])

# %%
# Remove unecessary columns
del_col = ['video_id','thumbnail_link','comments_disabled','ratings_disabled','video_error_or_removed','description']
us_df = us_df.drop(del_col, axis=1)

# %%
us_df.head(5)
# Out:
#   trending_date                                              title  \
# 0    2017-11-14                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1    2017-11-14  The Trump Presidency: Last Week Tonight with J...
# 2    2017-11-14  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3    2017-11-14                   Nickelback Lyrics: Real or Fake?
# 4    2017-11-14                           I Dare You: GOING BALD!?
#
#            channel_title  category_id              publish_time  \
# 0           CaseyNeistat           22 2017-11-13 17:13:01+00:00
# 1        LastWeekTonight           24 2017-11-13 07:30:00+00:00
# 2           Rudy Mancuso           23 2017-11-12 19:05:24+00:00
# 3  Good Mythical Morning           24 2017-11-13 11:00:04+00:00
# 4               nigahiga           24 2017-11-12 18:01:41+00:00
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# ...

# %%
us_df.dtypes
# Out:
# trending_date         datetime64[ns]
# title                         object
# channel_title                 object
# category_id                    int64
# publish_time     datetime64[ns, UTC]
# tags                          object
# views                          int64
# likes                          int64
# dislikes                       int64
# comment_count                  int64
# dtype: object

# %%
# Finding 
df_startus=us_df['publish_time']
df_endus=us_df['trending_date']
df_startus
df_endus
# Out:
# 0       2017-11-14
# 1       2017-11-14
# 2       2017-11-14
# 3       2017-11-14
# 4       2017-11-14
#            ...
# 40944   2018-06-14
# 40945   2018-06-14
# 40946   2018-06-14
# 40947   2018-06-14
# 40948   2018-06-14
# Name: trending_date, Length: 40949, dtype: datetime64[ns]

# %%
#remove timezone info from df_star
df_startus= df_startus.apply(lambda d: d.replace(tzinfo=None))

# %%
#calculate the trending duration of each video
df_durus=df_endus-df_startus
df_durus
# Out:
# 0        0 days 06:46:59
# 1        0 days 16:30:00
# 2        1 days 04:54:36
# 3        0 days 12:59:56
# 4        1 days 05:58:19
#               ...
# 40944   26 days 10:59:56
# 40945   26 days 22:59:54
# 40946   26 days 06:25:38
# 40947   27 days 06:59:56
# 40948   27 days 06:50:22
# Length: 40949, dtype: timedelta64[ns]

# %%
#add the trending_duration column in us_df
us_df['trending_duration']=df_durus
us_df
# Out:
#       trending_date                                              title  \
# 0        2017-11-14                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1        2017-11-14  The Trump Presidency: Last Week Tonight with J...
# 2        2017-11-14  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3        2017-11-14                   Nickelback Lyrics: Real or Fake?
# 4        2017-11-14                           I Dare You: GOING BALD!?
# ...             ...                                                ...
# 40944    2018-06-14                       The Cat Who Caught the Laser
# 40945    2018-06-14                         True Facts : Ant Mutualism
# 40946    2018-06-14  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947    2018-06-14                How Black Panther Should Have Ended
# 40948    2018-06-14  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# ...

# %%
# Change trending_date to datetime format
gb_df['trending_date'] = pd.to_datetime(gb_df['trending_date'],format='%y.%d.%m')

# %%
# Change publish_time to datetime format
gb_df['publish_time'] = pd.to_datetime(gb_df['publish_time'])

# %%
# Remove unecessary columns
del_col1 = ['video_id','thumbnail_link','comments_disabled','ratings_disabled','video_error_or_removed','description']
gb_df = gb_df.drop(del_col1, axis=1)

# %%
gb_df.dtypes
# Out:
# trending_date         datetime64[ns]
# title                         object
# channel_title                 object
# category_id                    int64
# publish_time     datetime64[ns, UTC]
# tags                          object
# views                          int64
# likes                          int64
# dislikes                       int64
# comment_count                  int64
# dtype: object

# %%
df_startgb=gb_df['publish_time']
df_endgb=gb_df['trending_date']
df_startgb
df_endgb
# Out:
# 0       2017-11-14
# 1       2017-11-14
# 2       2017-11-14
# 3       2017-11-14
# 4       2017-11-14
#            ...
# 38911   2018-06-14
# 38912   2018-06-14
# 38913   2018-06-14
# 38914   2018-06-14
# 38915   2018-06-14
# Name: trending_date, Length: 38916, dtype: datetime64[ns]

# %%
#remove timezone info from df_star
df_startgb= df_startus.apply(lambda d: d.replace(tzinfo=None))

# %%
#calculate the trending duration of each video
df_durgb=df_endgb-df_startgb
df_durgb
# Out:
# 0       0 days 06:46:59
# 1       0 days 16:30:00
# 2       1 days 04:54:36
# 3       0 days 12:59:56
# 4       1 days 05:58:19
#               ...
# 40944               NaT
# 40945               NaT
# 40946               NaT
# 40947               NaT
# 40948               NaT
# Length: 40949, dtype: timedelta64[ns]

# %%
#add the trending_duration column in us_df
gb_df['trending_duration']=df_durgb
gb_df
# Out:
#       trending_date                                              title  \
# 0        2017-11-14      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1        2017-11-14          Taylor Swift: …Ready for It? (Live) - SNL
# 2        2017-11-14         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3        2017-11-14  Goals from Salford City vs Class of 92 and Fri...
# 4        2017-11-14  Dashcam captures truck's near miss with child ...
# ...             ...                                                ...
# 38911    2018-06-14  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912    2018-06-14  Jacob Sartorius - Up With It (Official Music V...
# 38913    2018-06-14                 Anne-Marie - 2002 [Official Video]
# 38914    2018-06-14  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915    2018-06-14  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                     channel_title  category_id              publish_time  \
# ...

# %%
# Export dataframe to CSV
compression_opts = dict(method='zip',
                        archive_name='us_video.csv') 
us_df.to_csv('out_us.zip', index =False,
             compression=compression_opts)

# %%
# Export dataframe to CSV
compression_opts = dict(method='zip',
                        archive_name='gb_video.csv') 
gb_df.to_csv('out_gb.zip', index =False,
             compression=compression_opts)
