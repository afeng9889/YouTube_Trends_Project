# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import numpy as np
import os
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import ticker
import matplotlib.colors as mc

# %%
gb_df = pd.read_csv('GBvideos.csv')
us_df = pd.read_csv('USvideos.csv')
us_df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
us_df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
us_df['trending_date'] = pd.to_datetime(us_df['trending_date'],format='%y.%d.%m')

# %%
del_col = ['video_id','thumbnail_link','comments_disabled','ratings_disabled','video_error_or_removed','description','publish_time']
us_df = us_df.drop(del_col, axis=1)

# %%
us_df
# Out:
#       trending_date                                              title  \
# 0        2017-11-14                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1        2017-11-14  The Trump Presidency: Last Week Tonight with J...
# 2        2017-11-14  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3        2017-11-14                   Nickelback Lyrics: Real or Fake?
# 4        2017-11-14                           I Dare You: GOING BALD!?
# ...             ...                                                ...
# 40944    2018-06-14                       The Cat Who Caught the Laser
# 40945    2018-06-14                         True Facts : Ant Mutualism
# 40946    2018-06-14  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947    2018-06-14                How Black Panther Should Have Ended
# 40948    2018-06-14  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id  \
# 0                  CaseyNeistat           22
# ...

# %%
us_df.dtypes
# Out:
# trending_date    datetime64[ns]
# title                    object
# channel_title            object
# category_id               int64
# tags                     object
# views                     int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# dtype: object

# %%
new_us = us_df.set_index('trending_date')

# %%
# compression_opts = dict(method='zip',
#                         archive_name='out.csv') 
# new_us.to_csv('out.zip', index =False,
#              compression=compression_opts)

# %%
new_us.to_csv('usvids')

# %%
new_us
# Out:
#                                                            title  \
# trending_date
# 2017-11-14                    WE WANT TO TALK ABOUT OUR MARRIAGE
# 2017-11-14     The Trump Presidency: Last Week Tonight with J...
# 2017-11-14     Racist Superman | Rudy Mancuso, King Bach & Le...
# 2017-11-14                      Nickelback Lyrics: Real or Fake?
# 2017-11-14                              I Dare You: GOING BALD!?
# ...                                                          ...
# 2018-06-14                          The Cat Who Caught the Laser
# 2018-06-14                            True Facts : Ant Mutualism
# 2018-06-14     I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 2018-06-14                   How Black Panther Should Have Ended
# 2018-06-14     Official Call of Duty®: Black Ops 4 — Multipla...
#
#                           channel_title  category_id  \
# trending_date
# 2017-11-14                 CaseyNeistat           22
# ...

# %%
gb_df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %%
gb_df['trending_date'] = pd.to_datetime(gb_df['trending_date'],format='%y.%d.%m')

# %%
del_col1 = ['video_id','thumbnail_link','comments_disabled','ratings_disabled','video_error_or_removed','description','publish_time']
gb_df = gb_df.drop(del_col1, axis=1)

# %%
new_gb = gb_df.set_index('trending_date')

# %%
new_gb
# Out:
#                                                            title  \
# trending_date
# 2017-11-14         John Lewis Christmas Ad 2017 - #MozTheMonster
# 2017-11-14             Taylor Swift: …Ready for It? (Live) - SNL
# 2017-11-14            Eminem - Walk On Water (Audio) ft. Beyoncé
# 2017-11-14     Goals from Salford City vs Class of 92 and Fri...
# 2017-11-14     Dashcam captures truck's near miss with child ...
# ...                                                          ...
# 2018-06-14     Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 2018-06-14     Jacob Sartorius - Up With It (Official Music V...
# 2018-06-14                    Anne-Marie - 2002 [Official Video]
# 2018-06-14     Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 2018-06-14     KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                             channel_title  category_id  \
# trending_date
# 2017-11-14                     John Lewis           26
# ...

# %%
new_gb.to_csv('GB_videos')
