# %%
import pandas as pd

# %%
#  convert the publish_time to date time for US dataset

import pandas as pd
url = 'https://raw.githubusercontent.com/afeng9889/YouTube_Trends_Project/Andy-Feng/Resources/us_video.csv'
df = pd.read_csv(url,index_col=0,parse_dates=[0])

# %%
df
# Out:
#                                                                channel_title  \
# title
# WE WANT TO TALK ABOUT OUR MARRIAGE                              CaseyNeistat
# The Trump Presidency: Last Week Tonight with Jo...           LastWeekTonight
# Racist Superman | Rudy Mancuso, King Bach & Lel...              Rudy Mancuso
# Nickelback Lyrics: Real or Fake?                       Good Mythical Morning
# I Dare You: GOING BALD!?                                            nigahiga
# ...                                                                      ...
# The Cat Who Caught the Laser                                   AaronsAnimals
# True Facts : Ant Mutualism                                          zefrank1
# I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER B...                Brad Mondo
# How Black Panther Should Have Ended                 How It Should Have Ended
# Official Call of Duty®: Black Ops 4 — Multiplay...              Call of Duty
#
# ...

# %%
df["publish_time"]= pd.to_datetime(df["publish_time"]) 
  
# info of data 
df.info() 
  
# display 
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40949 entries, WE WANT TO TALK ABOUT OUR MARRIAGE to Official Call of Duty®: Black Ops 4 — Multiplayer Reveal Trailer
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   channel_title  40949 non-null  object
#  1   category_id    40949 non-null  int64
#  2   publish_time   40949 non-null  datetime64[ns, UTC]
#  3   tags           40949 non-null  object
#  4   views          40949 non-null  int64
#  5   likes          40949 non-null  int64
#  6   dislikes       40949 non-null  int64
#  7   comment_count  40949 non-null  int64
# dtypes: datetime64[ns, UTC](1), int64(5), object(2)
# memory usage: 2.8+ MB
#                                                                channel_title  \
# title
# WE WANT TO TALK ABOUT OUR MARRIAGE                              CaseyNeistat
# The Trump Presidency: Last Week Tonight with Jo...           LastWeekTonight
# ...

# %%
#  convert the publish_time to date time for US dataset

import pandas as pd
url = 'https://raw.githubusercontent.com/afeng9889/YouTube_Trends_Project/Andy-Feng/Resources/gb_video.csv'
df_gb = pd.read_csv(url,index_col=0,parse_dates=[0])

# %%
df_gb
# Out:
#                                                                  channel_title  \
# title
# John Lewis Christmas Ad 2017 - #MozTheMonster                       John Lewis
# Taylor Swift: …Ready for It? (Live) - SNL                  Saturday Night Live
# Eminem - Walk On Water (Audio) ft. Beyoncé                          EminemVEVO
# Goals from Salford City vs Class of 92 and Frie...  Salford City Football Club
# Dashcam captures truck's near miss with child i...            Cute Girl Videos
# ...                                                                        ...
# Enrique Iglesias - MOVE TO MIAMI (Official Vide...         EnriqueIglesiasVEVO
# Jacob Sartorius - Up With It (Official Music Vi...             Jacob Sartorius
# Anne-Marie - 2002 [Official Video]                                  Anne-Marie
# Eleni Foureira - Fuego - Cyprus - LIVE - First ...     Eurovision Song Contest
# KYLE - Ikuyo feat.  2 Chainz & Sophia Black [Au...              SuperDuperKyle
#
# ...

# %%
df_gb["publish_time"]= pd.to_datetime(df_gb["publish_time"]) 
  
# info of data 
df_gb.info() 
  
# display 
df_gb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38916 entries, John Lewis Christmas Ad 2017 - #MozTheMonster to KYLE - Ikuyo feat.  2 Chainz & Sophia Black [Audio]
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   channel_title  38916 non-null  object
#  1   category_id    38916 non-null  int64
#  2   publish_time   38916 non-null  datetime64[ns, UTC]
#  3   tags           38916 non-null  object
#  4   views          38916 non-null  int64
#  5   likes          38916 non-null  int64
#  6   dislikes       38916 non-null  int64
#  7   comment_count  38916 non-null  int64
# dtypes: datetime64[ns, UTC](1), int64(5), object(2)
# memory usage: 2.7+ MB
#                                                                  channel_title  \
# title
# John Lewis Christmas Ad 2017 - #MozTheMonster                       John Lewis
# Taylor Swift: …Ready for It? (Live) - SNL                  Saturday Night Live
# ...
