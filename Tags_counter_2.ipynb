# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import numpy as np
import os
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import ticker
import matplotlib.colors as mc
import statsmodels.formula.api as sm

# %%
gb_df = pd.read_csv('GBvideos.csv')
us_df = pd.read_csv('USvideos.csv')

# %%
# Remove unecessary columns
del_col = ['video_id','thumbnail_link','comments_disabled','ratings_disabled','video_error_or_removed','description']
us_df = us_df.drop(del_col, axis=1)

# %%
# Remove unecessary columns
del_col2 = ['video_id','thumbnail_link','comments_disabled','ratings_disabled','video_error_or_removed','description']
gb_df = gb_df.drop(del_col2, axis=1)

# %%
us_df
# Out:
#       trending_date                                              title  \
# 0          17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1          17.14.11  The Trump Presidency: Last Week Tonight with J...
# 2          17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3          17.14.11                   Nickelback Lyrics: Real or Fake?
# 4          17.14.11                           I Dare You: GOING BALD!?
# ...             ...                                                ...
# 40944      18.14.06                       The Cat Who Caught the Laser
# 40945      18.14.06                         True Facts : Ant Mutualism
# 40946      18.14.06  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947      18.14.06                How Black Panther Should Have Ended
# 40948      18.14.06  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# ...

# %%
us_df['tags']
# Out:
# 0                                          SHANtell martin
# 1        last week tonight trump presidency|"last week ...
# 2        racist superman|"rudy"|"mancuso"|"king"|"bach"...
# 3        rhett and link|"gmm"|"good mythical morning"|"...
# 4        ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...
#                                ...
# 40944    aarons animals|"aarons"|"animals"|"cat"|"cats"...
# 40945                                               [none]
# 40946    I gave safiya nygaard a perfect hair makeover ...
# 40947    Black Panther|"HISHE"|"Marvel"|"Infinity War"|...
# 40948        call of duty|"cod"|"activision"|"Black Ops 4"
# Name: tags, Length: 40949, dtype: object

# %%
tagsdict = {}
for tag in us_df['tags']:
    depiped = tag.split('|')
    for item in depiped:
        cleanitem = item.replace('"','')
        if cleanitem in tagsdict:
            tagsdict[cleanitem] += 1
        else:
            tagsdict[cleanitem] = 1

# %%
tagsseries = pd.Series(tagsdict)

# %%
tagsseries.sort_values(ascending=False).nlargest(11)
# Out:
# funny      3603
# comedy     2931
# how to     1604
# [none]     1535
# music      1302
# Pop        1280
# 2018       1275
# humor      1185
# food       1159
# science    1111
# review     1005
# dtype: int64

# %%
us_df[['category_id', 'views']][us_df['tags'].str.contains('funny')]
# Out:
#        category_id    views
# 3               24   343168
# 4               24  2095731
# 6               24  2103417
# 16              23   295639
# 24              23    33980
# ...            ...      ...
# 40906           23   661572
# 40916           24  2310794
# 40922           23   588133
# 40934           24  8607264
# 40943           22  8259128
#
# [4711 rows x 2 columns]

# %%
us_df[['category_id', 'views']][us_df['tags'].str.contains('comedy')]
# Out:
#        category_id    views
# 3               24   343168
# 4               24  2095731
# 6               24  2103417
# 16              23   295639
# 24              23    33980
# ...            ...      ...
# 40902           22  3464680
# 40906           23   661572
# 40922           23   588133
# 40934           24  8607264
# 40947            1  5660813
#
# [3310 rows x 2 columns]
